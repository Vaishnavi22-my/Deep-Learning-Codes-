# %%
import time
def fib(n,d):
  if n in d:
    return d[n]
  else:
    d[n] = fib(n-1 , d) + fib(n-2 ,d)
    return d[n]

# %%
start = time.time()
d = {0:1,1:1}
print(fib(100,d))
print(time.time() - start)
# Out:
# 573147844013817084101
# 0.0007314682006835938

# %% [markdown]
# # New Section

# %%
import numpy as np
import pandas as pd
import time

# %%
df = pd.read_csv('Social_Network_Ads.csv')

# %%
df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
X= df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
X
# Out:
#      Age  EstimatedSalary
# 0     19            19000
# 1     35            20000
# 2     26            43000
# 3     27            57000
# 4     19            76000
# ..   ...              ...
# 395   46            41000
# 396   51            23000
# 397   50            20000
# 398   36            33000
# 399   49            36000
#
# [400 rows x 2 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 395    1
# 396    1
# 397    1
# 398    0
# 399    1
# Name: Purchased, Length: 400, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_scaled = sc.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test = train_test_split(X_scaled,y, test_size=0.2 , random_state=2)

# %%
X_train.shape
# Out:
# (320, 2)

# %%
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(10, activation='relu', input_dim=2))
model.add(Dense(10, activation='relu'))
model.add(Dense(1,activation='sigmoid'))

model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_30 (Dense)                     │ (None, 10)                  │              30 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_31 (Dense)                     │ (None, 10)                  │             110 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_32 (Dense)                     │ (None, 1)                   │              11 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 151 (604.00 B)
#  Trainable params: 151 (604.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='binary_crossentropy' , optimizer='Adam',metrics=['accuracy'])
start=time.time()
history = model.fit(X_train,y_train,epochs =50,batch_size=32,validation_split=0.2)
print(time.time() - start)
# Out:
# Epoch 1/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.7894 - loss: 0.6206 - val_accuracy: 0.8281 - val_loss: 0.6127
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8361 - loss: 0.5825 - val_accuracy: 0.8281 - val_loss: 0.6058
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8241 - loss: 0.5815 - val_accuracy: 0.8281 - val_loss: 0.5994
# Epoch 4/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8091 - loss: 0.5829 - val_accuracy: 0.8281 - val_loss: 0.5928
# Epoch 5/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8079 - loss: 0.5812 - val_accuracy: 0.8281 - val_loss: 0.5862
# Epoch 6/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8107 - loss: 0.5618 - val_accuracy: 0.8281 - val_loss: 0.5795
# Epoch 7/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8229 - loss: 0.5699 - val_accuracy: 0.8281 - val_loss: 0.5727
# Epoch 8/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7937 - loss: 0.5562 - val_accuracy: 0.8281 - val_loss: 0.5652
# Epoch 9/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7911 - loss: 0.5541 - val_accuracy: 0.8281 - val_loss: 0.5574
# Epoch 10/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8301 - loss: 0.5614 - val_accuracy: 0.8281 - val_loss: 0.5487
# Epoch 11/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8290 - loss: 0.5193 - val_accuracy: 0.8438 - val_loss: 0.5404
# Epoch 12/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8287 - loss: 0.5470 - val_accuracy: 0.8594 - val_loss: 0.5323
# Epoch 13/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8669 - loss: 0.5089 - val_accuracy: 0.8594 - val_loss: 0.5249
# Epoch 14/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8514 - loss: 0.5030 - val_accuracy: 0.8594 - val_loss: 0.5173
# Epoch 15/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8426 - loss: 0.5027 - val_accuracy: 0.8594 - val_loss: 0.5092
# Epoch 16/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8522 - loss: 0.4922 - val_accuracy: 0.8594 - val_loss: 0.5013
# Epoch 17/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8472 - loss: 0.4965 - val_accuracy: 0.8594 - val_loss: 0.4931
# Epoch 18/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8454 - loss: 0.5029 - val_accuracy: 0.8594 - val_loss: 0.4849
# Epoch 19/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8203 - loss: 0.4726 - val_accuracy: 0.8594 - val_loss: 0.4772
# Epoch 20/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8362 - loss: 0.4795 - val_accuracy: 0.8594 - val_loss: 0.4685
# Epoch 21/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8658 - loss: 0.4364 - val_accuracy: 0.8594 - val_loss: 0.4602
# Epoch 22/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8647 - loss: 0.4314 - val_accuracy: 0.8594 - val_loss: 0.4525
# Epoch 23/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8635 - loss: 0.4279 - val_accuracy: 0.8594 - val_loss: 0.4449
# Epoch 24/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8477 - loss: 0.4256 - val_accuracy: 0.8594 - val_loss: 0.4366
# Epoch 25/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8323 - loss: 0.4495 - val_accuracy: 0.8594 - val_loss: 0.4280
# Epoch 26/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8506 - loss: 0.4061 - val_accuracy: 0.8594 - val_loss: 0.4204
# Epoch 27/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8523 - loss: 0.4129 - val_accuracy: 0.8594 - val_loss: 0.4122
# Epoch 28/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8468 - loss: 0.3899 - val_accuracy: 0.8594 - val_loss: 0.4038
# Epoch 29/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8336 - loss: 0.4097 - val_accuracy: 0.8594 - val_loss: 0.3957
# Epoch 30/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8612 - loss: 0.3788 - val_accuracy: 0.8594 - val_loss: 0.3885
# Epoch 31/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8618 - loss: 0.3687 - val_accuracy: 0.8594 - val_loss: 0.3811
# Epoch 32/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8579 - loss: 0.3701 - val_accuracy: 0.8594 - val_loss: 0.3729
# Epoch 33/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8692 - loss: 0.3781 - val_accuracy: 0.8594 - val_loss: 0.3652
# Epoch 34/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8673 - loss: 0.3711 - val_accuracy: 0.8750 - val_loss: 0.3581
# Epoch 35/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8497 - loss: 0.3748 - val_accuracy: 0.8750 - val_loss: 0.3509
# Epoch 36/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8925 - loss: 0.3448 - val_accuracy: 0.8750 - val_loss: 0.3443
# Epoch 37/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8563 - loss: 0.3834 - val_accuracy: 0.8750 - val_loss: 0.3374
# Epoch 38/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8947 - loss: 0.3460 - val_accuracy: 0.8750 - val_loss: 0.3307
# Epoch 39/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8777 - loss: 0.3109 - val_accuracy: 0.8750 - val_loss: 0.3253
# Epoch 40/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8555 - loss: 0.3298 - val_accuracy: 0.8750 - val_loss: 0.3192
# Epoch 41/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8872 - loss: 0.3179 - val_accuracy: 0.8906 - val_loss: 0.3141
# Epoch 42/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8634 - loss: 0.3230 - val_accuracy: 0.8906 - val_loss: 0.3091
# Epoch 43/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8657 - loss: 0.3278 - val_accuracy: 0.8906 - val_loss: 0.3040
# Epoch 44/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8684 - loss: 0.3348 - val_accuracy: 0.8906 - val_loss: 0.2988
# Epoch 45/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8904 - loss: 0.3312 - val_accuracy: 0.8906 - val_loss: 0.2942
# Epoch 46/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8697 - loss: 0.3171 - val_accuracy: 0.8906 - val_loss: 0.2904
# Epoch 47/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9077 - loss: 0.2598 - val_accuracy: 0.8906 - val_loss: 0.2864
# Epoch 48/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9020 - loss: 0.2717 - val_accuracy: 0.8906 - val_loss: 0.2830
# Epoch 49/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8888 - loss: 0.2700 - val_accuracy: 0.8906 - val_loss: 0.2799
# Epoch 50/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8915 - loss: 0.2923 - val_accuracy: 0.9062 - val_loss: 0.2762
# 6.811559200286865

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
